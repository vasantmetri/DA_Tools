# %%
print("aditya")
# Out:
# aditya

# %% [markdown]
# numpy is a numerical python
#
# numpy  is used to perform sintific
#
# numpy id 50x faster

# %%
# !pip install numpy

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
import numpy as np

# %%
type(np)
# Out:
# module

# %%
l1 = [21,12,'hello world']

# %%
l1
# Out:
# [21, 12, 'hello world']

# %%
type(l1)
# Out:
# list

# %% [markdown]
# Converting python list to numpy array

# %%
np.array(l1)
# Out:
# array(['21', '12', 'hello world'], dtype='<U21')

# %%
l2 = np.array(l1)

# %%
type(l2)
# Out:
# numpy.ndarray

# %% [markdown]
# Initialize array

# %%
arr1 = np.array([1,4,5,6,"Hellow world"])

# %%
arr1
# Out:
# array(['1', '4', '5', '6', 'Hellow world'], dtype='<U21')

# %%
type(arr1)
# Out:
# numpy.ndarray

# %% [markdown]
# Two dimential array

# %%
b=np.array([[1,3,2,1],[4,3,2,1]])

# %% [markdown]
# dimensions

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (2, 4)

# %% [markdown]
# Data type

# %%
b.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Size

# %%
b.size
# Out:
# 8

# %%
b.itemsize
# Out:
# 8

# %%
b.itemsize*b.size
# Out:
# 64

# %%
b[0:2,0]
# Out:
# array([1, 4])

# %%
b[0,1]=100

# %%
b[0,1:3]=[2,3]

# %%
b
# Out:
# array([[1, 2, 3, 1],
#        [4, 3, 2, 1]])

# %%
b[0,1:3]=[2,3]
